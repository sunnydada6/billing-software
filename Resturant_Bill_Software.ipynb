# %%
from tkinter import *
import math,random 
import os
import tempfile
from tkinter import messagebox  
           


       
    
    
class bill_app:
    def __init__(self,root):
        self.root=root
        self.root.geometry("1350x700+0+0")
        self.root.title("Resturant Billing Software") 
        #Variables 
                    #''' Break Fast Menu'''
        self.Tea=IntVar() 
        self.Coffee=IntVar() 
        self.Milk=IntVar()
        self.Cold_Drinks=IntVar() 
        self.Toast=IntVar()
        self.Butter=IntVar() 
                           
                         #''' Lunch Menu'''
                
        self.Veg_Biryani=IntVar()
        self.Pasta=IntVar()
        self.Momos=IntVar()
        self.Macroni=IntVar()
        self.Chilli_Potato=IntVar()
        self.Chole_Kulche=IntVar()   
        
                         #'''Dinner Menu'''
        self.Shahi_Paneer=IntVar()
        self.Fry_Rice=IntVar()
        self.Kadai_Paneer=IntVar()
        self.Veg_Mix=IntVar()
        self.Roti=IntVar()
        self.Rajma_Chawal=IntVar()   
        
                        #'''Total price and tax detail'''
        self.breakfast_price=StringVar()
        self.Lunch_price=StringVar()
        self.Dinner_price=StringVar() 
        
        self.breakfast_tax=StringVar()
        self.Lunch_tax=StringVar()
        self.Dinner_tax=StringVar() 
        
                            #'''Cutomer Detail'''
        self.c_name=StringVar()
        self.c_phone=StringVar()
        self.bill_no=StringVar() 
        x=random.randint(1000,9999)
        self.bill_no.set(str(x))
        self.search_bill=StringVar()
        
        
        
        
        
                
        
        
        
        bgcolor="#074463"
        title=Label(self.root,text="Billing Software",bd=12,relief=GROOVE,bg="#074463",fg="white",font=("times new roman",30,'bold'),pady=2).pack(fill=X)
        
        f1=LabelFrame(self.root,text="Customer details",bd=10,relief=GROOVE,font=("times new roman",15,'bold'),fg="gold",bg=bgcolor)
        f1.place(x=0,y=80,relwidth=1)
        
        cname_lbl=Label(f1,text="Customer Name",bg=bgcolor,fg="white",font=("times new roman",18,'bold')).grid(row=0,column=0,padx=20,pady=5)
        cname_text=Entry(f1,width=15,textvariable=self.c_name,font="arial 15",bd=7,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=5)
        
        cphone_lbl=Label(f1,text="Phone No",bg=bgcolor,fg="white",font=("times new roman",18,'bold')).grid(row=0,column=2,padx=20,pady=5)
        cphone_text=Entry(f1,width=15,textvariable=self.c_phone,font="arial 15",bd=7,relief=SUNKEN).grid(row=0,column=3,padx=10,pady=5)
        
        cbill_lbl=Label(f1,text=" Bill No",bg=bgcolor,fg="white",font=("times new roman",18,'bold')).grid(row=0,column=4,padx=20,pady=5)
        cbill_text=Entry(f1,width=15,textvariable=self.search_bill,font="arial 15",bd=7,relief=SUNKEN).grid(row=0,column=5,padx=10,pady=5)  
        
        
        bill_btn=Button(f1,text="Search",command=self.find_bill,width=10,bd=7,font="arial 12 bold").grid(row=0,column=6,padx=10,pady=10)
        
        #Breakfast Menu
        
        f2=LabelFrame(self.root,text="BREAKFAST MENU ",bd=10,relief=GROOVE,font=("times new roman",15,'bold'),fg="gold",bg=bgcolor)
        f2.place(x=5,y=180,width=325,height=380) 
        

        
        
      
        
        tea_lbl=Label(f2,text="Tea",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=1,column=0,padx=10,pady=10,sticky="w")
        tea_txt=Entry(f2,width=10,textvariable=self.Tea,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=10,pady=10) 
       
        
        coffee_lbl=Label(f2,text="Coffee",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=2,column=0,padx=10,pady=10,sticky="w")
        coffee_txt=Entry(f2,width=10,textvariable=self.Coffee,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=10)
        
        milk_lbl=Label(f2,text="Milk",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=3,column=0,padx=10,pady=10,sticky="w")
        milk_txt=Entry(f2,width=10,textvariable=self.Milk,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=10,pady=10)
        
        cold_lbl=Label(f2,text="Cold Drinks",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=4,column=0,padx=10,pady=10,sticky="w")
        cold_txt=Entry(f2,width=10,textvariable=self.Cold_Drinks,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=10,pady=10) 
        
        toast_lbl=Label(f2,text="Toast",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=5,column=0,padx=10,pady=10,sticky="w")
        toast_txt=Entry(f2,width=10,textvariable=self.Toast,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=10,pady=10)
        
        bt_lbl=Label(f2,text="Butter",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=6,column=0,padx=10,pady=10,sticky="w")
        bt_txt=Entry(f2,width=10,textvariable=self.Butter,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=10,pady=10) 
        
 
        
         
        
        #Launch Menu 
        
        f3=LabelFrame(self.root,text="LUNCH MENU ",bd=10,relief=GROOVE,font=("times new roman",15,'bold'),fg="gold",bg=bgcolor)
        f3.place(x=340,y=180,width=325,height=380) 
        
        vb_lbl=Label(f3,text="Veg Biryani",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=0,column=0,padx=10,pady=10,sticky="w")
        vb_txt=Entry(f3,width=10,textvariable=self.Veg_Biryani,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10) 
        
        p_lbl=Label(f3,text="Pasta",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=1,column=0,padx=10,pady=10,sticky="w")
        p_txt=Entry(f3,width=10,textvariable=self.Pasta,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=10,pady=10)
        
        m_lbl=Label(f3,text="Momos",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=2,column=0,padx=10,pady=10,sticky="w")
        m_txt=Entry(f3,width=10,textvariable=self.Momos,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=10)
        
        mc_lbl=Label(f3,text="Macroni",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=3,column=0,padx=10,pady=10,sticky="w")
        mc_txt=Entry(f3,width=10,textvariable=self.Macroni,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=10,pady=10) 
        
        ch_lbl=Label(f3,text="Chilli Potato",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=4,column=0,padx=10,pady=10,sticky="w")
        ch_txt=Entry(f3,width=10,textvariable=self.Chilli_Potato,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=10,pady=10)
        
        ck_lbl=Label(f3,text="Chole-kulche",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=5,column=0,padx=10,pady=10,sticky="w")
        ck_txt=Entry(f3,width=10,textvariable=self.Chole_Kulche,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=10,pady=10)  
        
        #Dinner Menu 
        
        f4=LabelFrame(self.root,text="DINNER MENU ",bd=10,relief=GROOVE,font=("times new roman",15,'bold'),fg="gold",bg=bgcolor)
        f4.place(x=670,y=180,width=325,height=380) 
        
        sh_lbl=Label(f4,text="Shahi Paneer",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=0,column=0,padx=10,pady=10,sticky="w")
        sh_txt=Entry(f4,width=10,textvariable=self.Shahi_Paneer,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10) 
        
        fr_lbl=Label(f4,text="Fry Rice",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=1,column=0,padx=10,pady=10,sticky="w")
        fr_txt=Entry(f4,width=10,textvariable=self.Fry_Rice,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=10,pady=10)
        
        kr_lbl=Label(f4,text="Kadai Paneer",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=2,column=0,padx=10,pady=10,sticky="w")
        kr_txt=Entry(f4,width=10,textvariable=self.Kadai_Paneer,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=10)
        
        vm_lbl=Label(f4,text="Veg Mix",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=3,column=0,padx=10,pady=10,sticky="w")
        vm_txt=Entry(f4,width=10,textvariable=self.Veg_Mix,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=10,pady=10) 
        
        r_lbl=Label(f4,text="Roti",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=4,column=0,padx=10,pady=10,sticky="w")
        r_txt=Entry(f4,width=10,textvariable=self.Roti,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=10,pady=10)
        
        rm_lbl=Label(f4,text="Rajma Chawal",font=("times new roman",16,'bold'),bg=bgcolor,fg="lightgreen").grid(row=5,column=0,padx=10,pady=10,sticky="w")
        rm_txt=Entry(f4,width=10,textvariable=self.Rajma_Chawal,font=("times new roman",16,'bold'),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=10,pady=10)  
        
        #Bill Area   
        
         
        f5=Frame(self.root,bd=10,relief=GROOVE)
        f5.place(x=1010,y=180,width=355,height=380)
        bill_title=Label(f5,text="Bill Area",font="arial 15 bold",bd=7,relief=GROOVE).pack(fill=X)
        scrol_y=Scrollbar(f5,orient=VERTICAL)
        self.textarea=Text(f5,yscroll=scrol_y.set)
        scrol_y.pack(side=RIGHT,fill=Y)
        scrol_y.config(command=self.textarea.yview)
        self.textarea.pack(fill=BOTH,expand=1)     
        
        #label
        f6=LabelFrame(self.root,text="BILL MENU ",bd=10,relief=GROOVE,font=("times new roman",15,'bold'),fg="gold",bg=bgcolor)
        f6.place(x=0,y=560,relwidth=1,height=140)  
        m1_lbl=Label(f6,text="Total breakfast price",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=0,column=0,padx=20,pady=1,sticky="w")
        m1_txt=Entry(f6,width=18,textvariable=self.breakfast_price,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=1) 
        
        m2_lbl=Label(f6,text="Total Lunch price",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=2,column=0,padx=20,pady=1,sticky="w")
        m2_txt=Entry(f6,width=18,textvariable=self.Lunch_price,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=1)
        
        m3_lbl=Label(f6,text="Total Dinner price",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=3,column=0,padx=20,pady=1,sticky="w")
        m3_txt=Entry(f6,width=18,textvariable=self.Dinner_price,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=3,column=1,padx=10,pady=1)
        
        c1_lbl=Label(f6,text="Breakfast Tax",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=0,column=2,padx=20,pady=1,sticky="w")
        c1_txt=Entry(f6,width=18,textvariable=self.breakfast_tax,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=0,column=3,padx=10,pady=1) 
        
        c2_lbl=Label(f6,text="Lunch Tax",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=2,column=2,padx=20,pady=1,sticky="w")
        c2_txt=Entry(f6,width=18,textvariable=self.Lunch_tax,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=2,column=3,padx=10,pady=1)
        
        c3_lbl=Label(f6,text="Dinner Tax",font=("times new roman",14,"bold"),bg=bgcolor,fg="white").grid(row=3,column=2,padx=20,pady=1,sticky="w")
        c3_txt=Entry(f6,width=18,textvariable=self.Dinner_tax,font="arial 10 bold",bd=7,relief=SUNKEN).grid(row=3,column=3,padx=10,pady=1)         
        
        btn_f=Frame(f6,bd=7,relief=GROOVE)
        btn_f.place(x=700,width=630,height=105) 
        
        total_btn=Button(btn_f,command=lambda:total(self),text="Total",bg="cadetblue",fg="white",bd=5,pady=15,width=10,font="arial 12 bold").grid(row=0,column=0,padx=5,pady=5)
        Gbill_btn=Button(btn_f,text="Generate Bill",command=self.bill_area,bg="cadetblue",fg="white",bd=5,pady=15,width=10,font="arial 12 bold").grid(row=0,column=1,padx=5,pady=5)
        send_btn=Button(btn_f,text="print Bill",command=self.iprint,bg="cadetblue",fg="white",bd=5,pady=15,width=10,font="arial 12 bold").grid(row=0,column=2,padx=5,pady=5)
        clear_btn=Button(btn_f,text="Clear",command=self.clear_bill,bg="cadetblue",fg="white",bd=5,pady=15,width=10,font="arial 12 bold").grid(row=0,column=3,padx=5,pady=5)
        Exit_btn=Button(btn_f,text="Exit",command=self.exit_app,bg="cadetblue",fg="white",bd=5,pady=15,width=8,font="arial 12 bold").grid(row=0,column=4,padx=5,pady=5)
        self.welcome_bill()
        
        def total(self):
            self.t_a=self.Tea.get()*40
            self.c_f= self.Coffee.get()*50
            self.m_k=self.Milk.get()*45
            self.c_d=self.Cold_Drinks.get()*55
            self.t_s=self.Toast.get()*30
            self.b_t=self.Butter.get()*20
            self.total_breakfast_price=(
                         
                          
                        
                             (self.t_a)+
                             (self.c_f)+
                             (self.m_k)+
                             (self.c_d)+
                             (self.t_s)+
                             (self.b_t)
                                     ) 
            self.breakfast_price.set("Rs. "+str(self.total_breakfast_price))
            self.b_tax=self.total_breakfast_price*0.05
            self.breakfast_tax.set("Rs. "+str(self.b_tax))
            
            
            self.v_b=self.Veg_Biryani.get()*120
            self.p_s=self.Pasta.get()*70
            self.m_s=self.Momos.get()*50
            self.m_c= self.Macroni.get()*60
            self.c_p=self.Chilli_Potato.get()*70
            self.c_k=self.Chole_Kulche.get()*40
            
        
            self.total_Lunch_price=(
                       
                
                             (self.v_b)+
                             (self.p_s)+
                             (self.m_s)+
                             (self.m_c)+
                             (self.c_p)+
                             (self.c_k)
                                     ) 
            self.Lunch_price.set("Rs. "+str(self.total_Lunch_price))
            self.l_tax=self.total_Lunch_price*0.1
            self.Lunch_tax.set("Rs. "+str(self.l_tax))
            
            
            self.s_p=self.Shahi_Paneer.get()*350
            self.f_r=self.Fry_Rice.get()*120
            self.k_p=self.Kadai_Paneer.get()*240
            self.v_m=self.Veg_Mix.get()*150
            self.r_t=self.Roti.get()*20
            self.r_m=self.Rajma_Chawal.get()*70
            
            self.total_Dinner_price=( 
                           
                           
                             (self.s_p)+
                             (self.f_r)+
                             (self.k_p)+
                             (self.v_m)+
                             (self.r_t)+
                             (self.r_m)
                                     ) 
            self.Dinner_price.set("Rs. "+str(self.total_Dinner_price))
            self.d_tax=self.total_Dinner_price*0.1
            self.Dinner_tax.set("Rs. "+str(self.d_tax))
            
            self.Total_bill=(self.total_breakfast_price+
                             self.total_Lunch_price+
                             self.total_Dinner_price+
                             self.b_tax+
                             self.l_tax+
                             self.d_tax
                            ) 
                              
            
 
    def welcome_bill(self):
        self.textarea.delete("1.0",END)
        self.textarea.insert(END,"\t---Welcome Raj Resturant---\n")
        self.textarea.insert(END,"\nBill Number:"+self.bill_no.get())
        self.textarea.insert(END,"\nCustomer Name:"+self.c_name.get())
        self.textarea.insert(END,"\nPhone Number:"+self.c_phone.get())
        self.textarea.insert(END,"\n=======================================")
        self.textarea.insert(END,"\tProduct\t\tQuantity\t\tPrice")
        self.textarea.insert(END,"\n=======================================")
   
    def bill_area(self):
        if self.c_name.get()=="" or self.c_phone.get()=="":
                 messagebox.showerror("Error","Customer Detail are Must")
        elif self.breakfast_price.get()=="Rs. 0" and self.Lunch_price.get()=="Rs. 0" and self.Dinner_price.get()=="Rs. 0" :
            messagebox.showerror("Error","No Product Purchased !")
        else:
            self.welcome_bill()
            
        if self.Tea.get()!=0:
            self.textarea.insert(END,f"\nTea\t\t{self.Tea.get()}\t\t{self.t_a}")
        if self.Coffee.get()!=0:
            self.textarea.insert(END,f"\nCoffee\t\t{self.Coffee.get()}\t\t{self.c_f}")
        if self.Milk.get()!=0:
            self.textarea.insert(END,f"\nMilk\t\t{self.Milk.get()}\t\t{self.m_k}")
        if self.Cold_Drinks.get()!=0:
            self.textarea.insert(END,f"\nCold Drinks\t\t{self.Cold_Drinks.get()}\t\t{self.c_d}")
        if self.Toast.get()!=0:
            self.textarea.insert(END,f"\nToast\t\t{self.Toast.get()}\t\t{self.t_s}")
        if self.Butter.get()!=0:
            self.textarea.insert(END,f"\nButter\t\t{self.Butter.get()}\t\t{self.b_t}")
            
        if self.Veg_Biryani.get()!=0:
            self.textarea.insert(END,f"\nVeg Biryani\t\t{self.Veg_Biryani.get()}\t\t{self.v_b}")
        if self.Pasta.get()!=0:
            self.textarea.insert(END,f"\nPasta\t\t{self.Pasta.get()}\t\t{self.p_s}")
        if self.Momos.get()!=0:
            self.textarea.insert(END,f"\nMomos\t\t{self.Momos.get()}\t\t{self.m_s}")
        if self.Macroni.get()!=0:
            self.textarea.insert(END,f"\nMacroni\t\t{self.Macroni.get()}\t\t{self.m_c}")   
            
        if self.Chilli_Potato.get()!=0:
            self.textarea.insert(END,f"\nChiLLi Poatato\t\t{self.Chilli_Potato.get()}\t\t{self.c_p}")     
            
        if self.Chole_Kulche.get()!=0:
            self.textarea.insert(END,f"\nChole Kulche\t\t{self.Chole_Kulche.get()}\t\t{self.c_k}")
            
        
        if self.Shahi_Paneer.get()!=0:
            self.textarea.insert(END,f"\nShahi Paneer\t\t{self.Shahi_Paneer.get()}\t\t{self.s_p}")
        if self.Fry_Rice.get()!=0:
            self.textarea.insert(END,f"\nPasta\t\t{self.Fry_Rice.get()}\t\t{self.f_r}")
        if self.Kadai_Paneer.get()!=0:
            self.textarea.insert(END,f"\nKadai Paneer\t\t{self.Kadai_Paneer.get()}\t\t{self.k_p}")
        if self.Veg_Mix.get()!=0:
            self.textarea.insert(END,f"\nVeg Mix\t\t{self.Veg_Mix.get()}\t\t{self.v_m}")   
            
        if self.Roti.get()!=0:
            self.textarea.insert(END,f"\nRoti\t\t{self.Roti.get()}\t\t{self.r_t}")     
            
        if self.Rajma_Chawal.get()!=0:
            self.textarea.insert(END,f"\nRajma Chawal\t\t{self.Rajma_Chawal.get()}\t\t{self.r_m}")
            
        
        
        if self.breakfast_tax.get()!="Rs. 0.0":
            self.textarea.insert(END,f"\nBreakFast Tax\t\t\t{self.breakfast_tax.get()}")
        if self.Lunch_tax.get()!="Rs. 0.0":
            self.textarea.insert(END,f"\nLunch Tax\t\t\t{self.Lunch_tax.get()}")
        if self.Dinner_tax.get()!="Rs. 0.0":
            self.textarea.insert(END,f"\nDinner Tax\t\t\t{self.Dinner_tax.get()}")
            
        
            
        self.textarea.insert(END,"\n=======================================") 
        self.textarea.insert(END,f"\nTotal Bill :\t\t\tRs.{+self.Total_bill}")
        self.textarea.insert(END,"\n=======================================") 
        self.save_bill()   
    
    def save_bill(self):
        op=messagebox.askyesno("Save Bill","Do you want to save the Bill?")
        if op>0:
            self.bill_data=self.textarea.get("1.0",END)
            f1=open("bills/"+str(self.bill_no.get())+".txt","w")
            f1.write(self.bill_data)
            f1.close()
            messagebox.showinfo("Saved",f"Bill no.{self.bill_no.get()} saved successfully")
        else:
            return                          
        
        
    
        
    def find_bill(self):
        present="no"
        for i in os.listdir("bills/"):
            if i.split('.')[0]==self.search_bill.get():
                f1=open(f"bills/{i}","r")
                self.textarea.delete("1.0",END)
                for d in f1:
                    self.textarea.insert(END,d)
                f1.close()
                present="yes"
        if present=="no":
            messagebox.showerror("Error","Invalid Bill No.") 
                
    def iprint(self):
        q=self.textarea.get("1.0","end-1c")
        filename=tempfile.mktemp(".txt")
        open(filename,'w').write(q)
        os.startfile(filename,"print")  


        
        
            
        
    def clear_bill(self):
        op=messagebox.askyesno("Clear","Do you really want to clear data?")
        if op>0:
            self.Tea.set(0)
            self.Coffee.set(0)
            self.Milk.set(0)
            self.Cold_Drinks.set(0)
            self.Toast.set(0)
            self.Butter.set(0) 
                           
                         #''' Lunch Menu'''
                
            self.Veg_Biryani.set(0)
            self.Pasta.set(0)
            self.Momos.set(0)
            self.Macroni.set(0)
            self.Chilli_Potato.set(0)
            self.Chole_Kulche.set(0)   
        
                         #'''Dinner Menu'''
            self.Shahi_Paneer.set(0)
            self.Fry_Rice.set(0)
            self.Kadai_Paneer.set(0)
            self.Veg_Mix.set(0)
            self.Roti.set(0)
            self.Rajma_Chawal.set(0)   
        
                        #'''Total price and tax detail'''
            self.breakfast_price.set("")
            self.Lunch_price.set("")
            self.Dinner_price.set("")
        
            self.breakfast_tax.set("")
            self.Lunch_tax.set("")
            self.Dinner_tax.set("") 
        
                            #'''Cutomer Detail'''
            self.c_name.set("")
            self.c_phone.set("")
            self.bill_no.set("")
            x=random.randint(1000,9999)
            self.bill_no.set(str(x))
            self.search_bill.set("")
            self.welcome_bill()
            
     
            

            
            
      
        
    def exit_app(self):
        
        op=messagebox.askyesno("Exit","Do you really want to exit?")
        if op>0:
            self.root.destroy()
            
        
            
                
root=Tk()  

obj=bill_app(root)
root.mainloop()
